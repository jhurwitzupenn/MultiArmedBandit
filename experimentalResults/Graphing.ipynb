# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
np.random.RandomState(10)

# %%
plt.plot(np.arange(0.0, .30, 0.01), [300.00000000000631,
 171.56400000000045,
 127.67399999999965,
 99.086999999999293,
 94.526999999999504,
 82.348999999999592,
 78.25599999999956,
 86.363999999999493,
 69.599999999999795,
 81.935999999999623,
 81.315999999999661,
 88.910999999999675,
 85.18899999999978,
 83.730999999999852,
 89.31999999999978,
 94.961999999999748,
 100.93699999999977,
 103.83899999999983,
 102.60799999999983,
 105.90499999999989,
 112.09899999999979,
 115.78799999999983,
 114.60599999999998,
 125.77199999999972,
 123.4759999999999,
 129.79299999999989,
 135.49599999999981,
 134.93999999999997,
 140.0389999999999,
 147.88499999999979], 'ro')
plt.xlabel('Epsilon')
plt.ylabel('Average Regrets')
plt.savefig("epsilonGreedyRegrets.png")
plt.show()

# %%
plt.plot(np.arange(0.0, .30, 0.01), [300.00000000000631,
 224.14800000000162,
 173.26400000000172,
 185.21500000000142,
 148.0840000000008,
 116.97500000000053,
 98.147999999999882,
 100.91299999999956,
 81.454999999999259,
 96.567999999999415,
 99.72999999999891,
 74.623999999999128,
 100.63499999999912,
 97.255999999998636,
 87.027999999999025,
 99.437999999998866,
 100.93299999999864,
 106.83199999999898,
 108.87899999999871,
 114.18699999999905,
 117.52599999999907,
 112.88099999999895,
 115.98099999999904,
 121.79699999999919,
 123.87899999999904,
 133.86699999999931,
 126.9049999999995,
 133.74499999999927,
 142.61099999999905,
 145.85599999999914], 'ro')
plt.xlabel('Epsilon')
plt.ylabel('Average Regrets')
plt.savefig("epsilonFirstRegrets.png")
plt.show()

# %%
plt.plot(np.arange(0.01, .3, 0.01), [45.814000000000114,
 45.484000000000115,
 46.234000000000108,
 49.127000000000109,
 49.207000000000114,
 48.997000000000114,
 51.927000000000106,
 50.98100000000013,
 52.605000000000139,
 55.071000000000147,
 56.330000000000119,
 54.061000000000121,
 55.599000000000132,
 53.772000000000126,
 57.110000000000134,
 57.210000000000136,
 57.460000000000157,
 57.390000000000121,
 58.284000000000127,
 60.314000000000107,
 59.466000000000086,
 59.766000000000119,
 60.180000000000064,
 58.838000000000093,
 62.322000000000095,
 60.864000000000097,
 61.568000000000104,
 62.514000000000088,
 63.940000000000111], 'ro')
plt.xlabel('Alpha')
plt.ylabel('Average Regrets')
plt.savefig("UCB2.png")
plt.show()

# %%
plt.plot(np.arange(0.01, .3, 0.01), [244.51599999999962,
 248.41200000000012,
 243.87200000000038,
 225.57099999999915,
 201.74299999999883,
 188.5919999999995,
 133.11699999999945,
 141.65999999999943,
 110.15199999999899,
 99.26599999999911,
 95.319999999999496,
 85.678999999999633,
 87.854999999999649,
 95.403999999999627,
 100.4339999999997,
 111.09199999999956,
 117.84799999999964,
 123.83899999999957,
 138.90099999999956,
 144.05899999999946,
 148.57799999999949,
 159.98299999999929,
 168.18599999999935,
 176.32899999999935,
 182.42499999999939,
 190.88499999999928,
 196.18699999999924,
 202.38799999999927,
 210.11599999999933], 'ro')
plt.xlabel('Temperature')
plt.ylabel('Average Regrets')
plt.savefig("softMax.png")
plt.show()
